# %%
def hello():
  print('hello')

hello()
# Out:
# hello

# %%
def hello(msg):
  print(msg)

hello('hello')
hello('good morning')
# Out:
# hello
# good morning

# %%
def hello(x,y=10):
  z=x+y
  print(z)

hello(10)
# Out:
# 20

# %%
def hello(name,age):
  msg=f'{name}is{age}years old'
  print(msg)

hello('t',20)
# Out:
# tis20years old

# %%
def a(x,y):
  result=x+y*2
  return result

b=a(1,2)
c=a(2,3)
print(b,c)
# Out:
# 5 8

# %%
def a(x):
  result=0
  while result < 10:
    result=result+x
    if result==5:
      return result
  return result

b=a(1)
c=a(2)
print(b,c)
# Out:
# 5 10

# %%
def tf(value):
 return 2 * value - 1
test_values = [1.0, 0.0012, 0.26, 0.4,0,53, 0.55, 2.0]
scaled_values = [tf(value) for value in test_values]
print("Original values: ", test_values)
print("Scaled values: ", scaled_values)
# Out:
# Original values:  [1.0, 0.0012, 0.26, 0.4, 0, 53, 0.55, 2.0]
# Scaled values:  [1.0, -0.9976, -0.48, -0.19999999999999996, -1, 105, 0.10000000000000009, 3.0]

# %%
def a(n):
  if n==0 or n == 1:
    return 1
  else:
      return n+a(n-1)

print(a(3))
# Out:
# 6

# %%
with open('test.txt','w')as f1:
  f1.write('good morning')

# %%
import datetime
print(datetime.datetime.now())
print(datetime.date.today())
a=((datetime.date.today()),(datetime.datetime.now()))
with open('test.txt','w')as f1:
  f1.write('datetime')
# Out:
# 2024-09-26 08:59:03.048995
# 2024-09-26

# %%
import datetime as dd
with open('test.txt','w')as f1:
  f1.write(str(dd.datetime.now()))
print(dd.datetime.now())
print(dd.date.today())
# Out:
# 2024-09-26 09:01:58.941841
# 2024-09-26

# %%
import numpy as np
import pandas as pd
s = pd.Series([1, 3, 5, np.nan, 6, 8])
print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
import numpy as np
import pandas as pd
dates = pd.date_range("20130101", periods=6)
dates
df = pd.DataFrame(np.random.randn(6, 4), index=dates,
columns=list("ABCD"))
df
print(df)
# Out:
#                    A         B         C         D
# 2013-01-01  1.330319  0.895646  0.515898 -0.567037
# 2013-01-02  0.550309  0.646779  1.448688 -0.841850
# 2013-01-03 -0.147678 -0.683198 -0.555783 -0.351389
# 2013-01-04  1.296966 -0.639210 -0.775735 -1.845139
# 2013-01-05 -0.897015 -1.527338 -0.038334 -0.507703
# 2013-01-06 -0.726793  0.619706 -0.096108 -0.098246

# %%
df.head()
df.tail(3)
df.index
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df2 = df.copy()
df2.to_numpy()
# Out:
# array([[ 1.33031921,  0.89564649,  0.51589755, -0.56703674],
#        [ 0.55030888,  0.64677875,  1.44868819, -0.84184962],
#        [-0.14767798, -0.68319825, -0.55578332, -0.35138896],
#        [ 1.2969655 , -0.63920989, -0.77573451, -1.8451394 ],
#        [-0.89701482, -1.52733785, -0.03833382, -0.50770311],
#        [-0.72679315,  0.61970551, -0.09610822, -0.09824613]])

# %%
a=df.describe()
print(a)
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.234351 -0.114603  0.083104 -0.701894
# std    0.977738  0.973021  0.805577  0.611513
# min   -0.897015 -1.527338 -0.775735 -1.845139
# 25%   -0.582014 -0.672201 -0.440865 -0.773146
# 50%    0.201315 -0.009752 -0.067221 -0.537370
# 75%    1.110301  0.640010  0.377340 -0.390467
# max    1.330319  0.895646  1.448688 -0.098246

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.330319  0.895646  0.515898 -0.567037
# 2013-01-02  0.550309  0.646779  1.448688 -0.841850
# 2013-01-03 -0.147678 -0.683198 -0.555783 -0.351389
# 2013-01-04  1.296966 -0.639210 -0.775735 -1.845139
# 2013-01-05 -0.897015 -1.527338 -0.038334 -0.507703
# 2013-01-06 -0.726793  0.619706 -0.096108 -0.098246

# %%
df3=df.T
df3
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    1.330319    0.550309   -0.147678    1.296966   -0.897015   -0.726793
# B    0.895646    0.646779   -0.683198   -0.639210   -1.527338    0.619706
# C    0.515898    1.448688   -0.555783   -0.775735   -0.038334   -0.096108
# D   -0.567037   -0.841850   -0.351389   -1.845139   -0.507703   -0.098246

# %%
df4=df.sort_index(axis=0, ascending=False)
df4
# Out:
#                    A         B         C         D
# 2013-01-06 -0.726793  0.619706 -0.096108 -0.098246
# 2013-01-05 -0.897015 -1.527338 -0.038334 -0.507703
# 2013-01-04  1.296966 -0.639210 -0.775735 -1.845139
# 2013-01-03 -0.147678 -0.683198 -0.555783 -0.351389
# 2013-01-02  0.550309  0.646779  1.448688 -0.841850
# 2013-01-01  1.330319  0.895646  0.515898 -0.567037

# %%
df["A"][0:1]
print(df[0:1])
# Out:
#                    A         B         C         D
# 2013-01-01  1.330319  0.895646  0.515898 -0.567037

# %%
df.loc[dates[0]]
df.loc[:, ["A", "B"]]
df.loc["20130102":"20130104", ["A", "B"]]
df.loc[dates[0], "A"]
# Out:
# 1.3303192097057701

# %%
print(df.iloc[3])
print(df.iloc[3:5, 0:2])
print(df.iloc[1:3, :])
# Out:
# A    1.296966
# B   -0.639210
# C   -0.775735
# D   -1.845139
# Name: 2013-01-04 00:00:00, dtype: float64
#                    A         B
# 2013-01-04  1.296966 -0.639210
# 2013-01-05 -0.897015 -1.527338
#                    A         B         C         D
# 2013-01-02  0.550309  0.646779  1.448688 -0.841850
# 2013-01-03 -0.147678 -0.683198 -0.555783 -0.351389

# %%
print(df[df > 0])
print(df[df["A"] > 0])
# Out:
#                    A         B         C   D
# 2013-01-01  1.330319  0.895646  0.515898 NaN
# 2013-01-02  0.550309  0.646779  1.448688 NaN
# 2013-01-03       NaN       NaN       NaN NaN
# 2013-01-04  1.296966       NaN       NaN NaN
# 2013-01-05       NaN       NaN       NaN NaN
# 2013-01-06       NaN  0.619706       NaN NaN
#                    A         B         C         D
# 2013-01-01  1.330319  0.895646  0.515898 -0.567037
# 2013-01-02  0.550309  0.646779  1.448688 -0.841850
# 2013-01-04  1.296966 -0.639210 -0.775735 -1.845139

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2[df2["E"].isin(["two", "four"])]
print(df2)
# Out:
#                    A         B         C         D      E
# 2013-01-01  1.330319  0.895646  0.515898 -0.567037    one
# 2013-01-02  0.550309  0.646779  1.448688 -0.841850    one
# 2013-01-03 -0.147678 -0.683198 -0.555783 -0.351389    two
# 2013-01-04  1.296966 -0.639210 -0.775735 -1.845139  three
# 2013-01-05 -0.897015 -1.527338 -0.038334 -0.507703   four
# 2013-01-06 -0.726793  0.619706 -0.096108 -0.098246  three

# %%
df2 = df.copy()
df2[df2 > 1] = -df2
print(df2)
# Out:
#                    A         B         C         D
# 2013-01-01 -1.330319  0.895646  0.515898 -0.567037
# 2013-01-02  0.550309  0.646779 -1.448688 -0.841850
# 2013-01-03 -0.147678 -0.683198 -0.555783 -0.351389
# 2013-01-04 -1.296966 -0.639210 -0.775735 -1.845139
# 2013-01-05 -0.897015 -1.527338 -0.038334 -0.507703
# 2013-01-06 -0.726793  0.619706 -0.096108 -0.098246

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0] : dates[1], "E"] = 1
df1.dropna( )
# Out:
#                    A         B         C         D    E
# 2013-01-01  1.330319  0.895646  0.515898 -0.567037  1.0
# 2013-01-02  0.550309  0.646779  1.448688 -0.841850  1.0

# %%
df1.fillna(5)
# Out:
#                    A         B         C         D    E
# 2013-01-01  1.330319  0.895646  0.515898 -0.567037  1.0
# 2013-01-02  0.550309  0.646779  1.448688 -0.841850  1.0
# 2013-01-03 -0.147678 -0.683198 -0.555783 -0.351389  5.0
# 2013-01-04  1.296966 -0.639210 -0.775735 -1.845139  5.0

# %%
df1.interpolate( )
# Out:
#                    A         B         C         D    E
# 2013-01-01  1.330319  0.895646  0.515898 -0.567037  1.0
# 2013-01-02  0.550309  0.646779  1.448688 -0.841850  1.0
# 2013-01-03 -0.147678 -0.683198 -0.555783 -0.351389  1.0
# 2013-01-04  1.296966 -0.639210 -0.775735 -1.845139  1.0

# %%
df.mean()
# Out:
# A    0.234351
# B   -0.114603
# C    0.083104
# D   -0.701894
# dtype: float64

# %%
df.std()
# Out:
# A    0.977738
# B    0.973021
# C    0.805577
# D    0.611513
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    0.543707
# 2013-01-02    0.450982
# 2013-01-03   -0.434512
# 2013-01-04   -0.490780
# 2013-01-05   -0.742597
# 2013-01-06   -0.075360
# Freq: D, dtype: float64

# %%
df.std(axis = 1)
# Out:
# 2013-01-01    0.811818
# 2013-01-02    0.951321
# 2013-01-03    0.235042
# 2013-01-04    1.308123
# 2013-01-05    0.630033
# 2013-01-06    0.550283
# Freq: D, dtype: float64
